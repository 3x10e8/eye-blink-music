# %%
import mne
import numpy as np
from glob import glob
from sys import platform
import os
from blink_utils import *
import mat73

# %% [markdown]
# # Path to FIF files

# %%
SUBJECT = 4

FIF_PATH = os.path.join('..', '..', '2-mat-to-npy-fif', 'fif')
BLINK_SUMMARY_PATH = os.path.join(
    '..', 
    '..', 
    '3-find-blinks', 
    '3.1-eeglab-blinker', 
    'blinkerDumpDir', 
    f'dataSub{SUBJECT}_BlinkSummary.mat',
)

# output paths
MERGED_FIF_PATH = 'merged-fif'

# %%
DATA_FILES = glob(os.path.join(FIF_PATH, f'subject-{SUBJECT}_*.fif'))
DATA_FILES = list(set(DATA_FILES)) # only get unique paths, sub3 is somehow returning trial 66 twice
DATA_FILES = sorted(DATA_FILES) # to sort by run#
DATA_FILES
# Out:
# ['../../2-mat-to-npy-fif/fif/subject-4_trial-00_chor-096_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-01_chor-096_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-02_chor-038_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-03_chor-101_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-04_chor-101_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-05_chor-096_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-06_chor-096_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-07_chor-096_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-08_chor-096_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-09_chor-038_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-10_chor-019_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-11_chor-096_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-12_chor-096_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-13_chor-096_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-14_chor-038_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-15_chor-038_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-16_chor-101_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-17_chor-019_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-18_chor-019_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-19_chor-101_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-20_chor-019_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-21_chor-019_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-22_chor-096_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-23_chor-101_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-24_chor-019_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-25_chor-019_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-26_chor-038_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-27_chor-038_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-28_chor-038_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-29_chor-101_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-30_chor-101_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-31_chor-101_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-32_chor-019_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-33_chor-038_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-34_chor-038_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-35_chor-101_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-36_chor-101_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-37_chor-019_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-38_chor-096_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-39_chor-096_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-40_chor-038_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-41_chor-101_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-42_chor-101_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-43_chor-019_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-44_chor-096_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-45_chor-096_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-46_chor-038_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-47_chor-101_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-48_chor-101_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-49_chor-096_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-50_chor-096_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-51_chor-096_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-52_chor-038_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-53_chor-038_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-54_chor-019_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-55_chor-096_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-56_chor-096_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-57_chor-096_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-58_chor-038_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-59_chor-038_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-60_chor-101_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-61_chor-019_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-62_chor-019_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-63_chor-101_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-64_chor-019_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-65_chor-019_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-66_chor-038_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-67_chor-101_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-68_chor-019_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-69_chor-019_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-70_chor-038_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-71_chor-038_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-72_chor-038_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-73_chor-101_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-74_chor-101_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-75_chor-101_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-76_chor-019_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-77_chor-038_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-78_chor-038_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-79_chor-101_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-80_chor-019_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-81_chor-019_condition-Listening_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-82_chor-096_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-83_chor-096_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-84_chor-038_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-85_chor-101_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-86_chor-019_condition-Imagery_raw.fif',
#  '../../2-mat-to-npy-fif/fif/subject-4_trial-87_chor-019_condition-Imagery_raw.fif']

# %%
print(len(DATA_FILES))
assert len(DATA_FILES)==11*8
# Out:
# 88

# %% [markdown]
# Combine all raws for one subject (that is one recording session)

# %%
RAWS_SUB = {}

for DATA_FILE in DATA_FILES: #[:2*5]:
    
    raw = mne.io.read_raw_fif(DATA_FILE, preload=True)
    fname = str(raw.filenames[0]).split(os.path.sep)[-1].rstrip('_raw.fif')
    
    toks = fname.split('_')
    subject = int(toks[0].split('-')[-1])
    condition = toks[2] + '/' + toks[3].lstrip('condition-')

    if not subject in RAWS_SUB:
        RAWS_SUB[subject] = []
    RAWS_SUB[subject].append(raw)
    
    #print(fname, subject, condition, run)
print(RAWS_SUB)
# Out:
# Opening raw data file ../../2-mat-to-npy-fif/fif/subject-4_trial
condition-Listening_raw.fif, 68 x 1803 (28.2 s), ~1.0 MiB, data loaded>,
#  <Raw | subject-4_trial-79_chor-101_condition-Listening_raw.fif, 68 x 1803 (28.2 s), ~1.0 MiB, data loaded>,
#  <Raw | subject-4_trial-80_chor-019_condition-Listening_raw.fif, 68 x 1803 (28.2 s), ~1.0 MiB, data loaded>,
#  <Raw | subject-4_trial-81_chor-019_condition-Listening_raw.fif, 68 x 1803 (28.2 s), ~1.0 MiB, data loaded>,
#  <Raw | subject-4_trial-82_chor-096_condition-Imagery_raw.fif, 68 x 1803 (28.2 s), ~1.0 MiB, data loaded>,
#  <Raw | subject-4_trial-83_chor-096_condition-Imagery_raw.fif, 68 x 1803 (28.2 s), ~1.0 MiB, data loaded>,
#  <Raw | subject-4_trial-84_chor-038_condition-Imagery_raw.fif, 68 x 1803 (28.2 s), ~1.0 MiB, data loaded>,
#  <Raw | subject-4_trial-85_chor-101_condition-Imagery_raw.fif, 68 x 1803 (28.2 s), ~1.0 MiB, data loaded>,
#  <Raw | subject-4_trial-86_chor-019_condition-Imagery_raw.fif, 68 x 1803 (28.2 s), ~1.0 MiB, data loaded>,
#  <Raw | subject-4_trial-87_chor-019_condition-Imagery_raw.fif, 68 x 1803 (28.2 s), ~1.0 MiB, data loaded>]

# %%
merged_raws = mne.concatenate_raws(RAWS_SUB[SUBJECT])
merged_raws
# Out:
# <Raw | subject-4_trial-00_chor-096_condition-Listening_raw.fif, 68 x 158664 (2479.1 s), ~82.4 MiB, data loaded>

# %%
# %matplotlib widget 
scalings = {'eeg': 10e-3}

merged_raws.plot(
    scalings = scalings,
    n_channels = 64,
    start = 0, 
    duration = 30, #28.125, #2.4*6,
    picks = ['Fp1', 'Fp2', 'AF7', 'AF8', 'Afz', 'T7', 'T8']
)
# Out:
# Using matplotlib as 2D backend.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <MNEBrowseFigure size 1600x800 with 4 Axes>

# %%
note_annot = merged_raws.annotations
boundary_annot = note_annot[note_annot.description == 'BAD boundary']

# %%
blink_summary = {}

if not SUBJECT in blink_summary.keys():
    blink_summary[SUBJECT] = mat73.loadmat(BLINK_SUMMARY_PATH)
    
blinks = blink_summary[SUBJECT]['blinks']
status = blinks['status']
print(f'Subject {SUBJECT}: {status}')

if type(blinks['signalData']) == list:
    n_signals = len(blinks['signalData'])
    print(f'# signals = {n_signals}')
    usedSignalIdx = np.where([x['signalNumber'] for x in blinks['signalData']] == blinks['usedSignal'])[0][0]
    signal = blinks['signalData'][usedSignalIdx]['signal']
    signalLabel = blinks['signalData'][usedSignalIdx]['signalLabel']
    numberBlinks = int(blinks['signalData'][usedSignalIdx]['numberBlinks'])
    numberGoodBlinks = int(blinks['signalData'][usedSignalIdx]['numberGoodBlinks'])
else:
    signal = blinks['signalData']['signal']
    signalLabel = blinks['signalData']['signalLabel']
    numberBlinks = int(blinks['signalData']['numberBlinks'])
    numberGoodBlinks = int(blinks['signalData']['numberGoodBlinks'])

blinkFits = blink_summary[SUBJECT]['blinkFits']
maxFrame = [int(x)-1 for x in blinkFits['maxFrame']] # convert to 0 index

# blinkPositions[:, 2]

blinkProperties = blink_summary[SUBJECT]['blinkProperties']

usedSignal = blinks['usedSignal']

print('usedSignal', usedSignal)
print('signalLabel:', signalLabel)
print('Total blinks:', numberBlinks)
print('Good blinks:', numberGoodBlinks)
# Out:
# Subject 4: failure: [Good ratio too low]
# usedSignal -1.0
# signalLabel: channel1
# Total blinks: 464
# Good blinks: 294

# %%
params = blink_summary[SUBJECT]['params']

blinkAmpRange = params['blinkAmpRange']
goodRatioThreshold = params['goodRatioThreshold']
highCutoffHz = params['highCutoffHz']
lowCutoffHz = params['lowCutoffHz']
stdThreshold = params['stdThreshold']
shutAmpFraction = params['shutAmpFraction']
pAVRThreshold = params['pAVRThreshold']
zThresholds = params['zThresholds']
correlationThresholdTop = params['correlationThresholdTop']
correlationThresholdMiddle = params['correlationThresholdMiddle']
correlationThresholdBottom = params['correlationThresholdBottom']

for keys in [
    'stdThreshold',
    'lowCutoffHz',
    'highCutoffHz',
    'correlationThresholdBottom'
]:
    print(keys, params[keys])
# Out:
# stdThreshold 2.5
# lowCutoffHz 1.0
# highCutoffHz 20.0
# correlationThresholdBottom 0.9

# %%
mne.set_config('MNE_BROWSE_RAW_SIZE','18,10') # https://mne.discourse.group/t/can-adjust-raw-plot-figure-size-using-rc-settings-in-v-24/3926/5
# %matplotlib widget

# %%
not_detected = [85, 519, 743.5, 877, 1718, 1796, 1861, 2246] # questionable blinks not detected by BLINKER at all

t_manual_blinks = [4, 10, 28, 80, 81, 84.5, 89, 90, 109, 112, 126, 131, 134, 139, 167, 210, 217, 220, 222, 240, 254, 259, 275, 306, 310, 312, 341, 345, 346, 384, 393, 447, 452, 486]
t_manual_blinks.extend([514, 515, 518, 520, 528, 644, 651, 653, 661, 727, 729, 745, 753, 762, 817, 843, 892, 898, 946, 959, 963, 967, 970.5, 974, 977, 989, 998])
t_manual_blinks.extend([1002, 1030, 1033, 1064, 1068, 1087, 1096, 1173, 1285, 1286, 1299, 1301, 1310, 1314, 1315, 1317, 1319, 1321, 1357, 1359, 1372, 1373, 1388])
t_manual_blinks.extend([1606, 1646, 1651, 1715, 1853, 1866, 1871, 1877, 1881, 1894, 1896, 1898, 1900, 1903, 1909])
t_manual_blinks.extend([2016, 2020, 2022, 2053, 2082, 2085, 2140, 2198, 2204, 2211, 2212, 2213, 2214, 2215, 2219, 2228, 2233, 2241, 2246, 2252, 2253, 2291])
    
t_bad_blinker = [60, 84, 132, 138, 158, 224, 291, 332, 354, 377, 379, 441, 476, 478, 492, 533, 749, 1297, 1663, 1683, 1695, 1822, 2190, 2439]
t_bad_saccades = None

# Add blink annotations (note annots will be added back later)
plot_annot(
    merged_raws, 
    boundary_annot, 
    blink_summary, 
    SUBJECT,
    usedSignalIdx = None,
    t_manual_blinks = t_manual_blinks,
    t_bad_blinker = t_bad_blinker,
    t_bad_saccades = t_bad_saccades,
    butterfly = False,
    highpass = None, #.1,
    lowpass = None, #30,
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Make a new raw object

# %%
final_raw = make_new_raw(
    merged_raws,
    signal, # blink IC
    usedSignal, # label of the blink IC
    note_annot, # note and break annotations
)
# Out:
# Used Annotations descriptions: ['BAD blinker', 'BAD boundary', 'blinker', 'manual']
# 'sweep'
# Total valid blinks: 314
# Total sweeps: 0

# %%
final_raw.plot(
    scalings = {'eeg': 1e-3, 'misc': 200e-6},
    duration = 30,
    butterfly = True,
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <MNEBrowseFigure size 1800x1000 with 4 Axes>

# %%
overwrite = True
final_raw.save(
    fname = os.path.join(MERGED_FIF_PATH, f'subject-{SUBJECT}_blinks_merged_raw.fif'),
    overwrite = overwrite
)
# Out:
# Writing /local_disk/abhinav/eye-blink-music/3-find-blinks/3.2-manually-select-blinker-blinks/merged-fif/subject-4_blinks_merged_raw.fif
# Closing /local_disk/abhinav/eye-blink-music/3-find-blinks/3.2-manually-select-blinker-blinks/merged-fif/subject-4_blinks_merged_raw.fif
# [done]
# [PosixPath('/local_disk/abhinav/eye-blink-music/3-find-blinks/3.2-manually-select-blinker-blinks/merged-fif/subject-4_blinks_merged_raw.fif')]
